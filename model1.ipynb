# %%
from ultralytics import YOLO

# %%
model = YOLO("yolov8n.pt")

# %%
results = model.train(data="data.yaml",epochs=10,imgsz=254,name="yolov8n.pt")
# Out:
# Ultralytics 8.3.241  Python-3.10.11 torch-2.9.1+cpu CPU (Intel Core(TM) i7-9850H 2.60GHz)
# ...
